# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %%
ed = Website("https://edwarddonner.com")
print(ed.get_contents())
# Out:
# Webpage Title:
# Home - Edward Donner
# Webpage Contents:
# Home
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy DJing (but I’m badly out of practice), amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of
# Nebula.io
# . We’re applying AI to a field where it can make a massive, positive impact: helping people discover their potential and pursue their reason for being. Recruiters use our product today to source, understand, engage and manage talent. I’m previously the founder and CEO of AI startup untapt,
# acquired in 2021
# .
# We work with groundbreaking, proprietary LLMs verticalized for talent, we’ve
# patented
# our matching model, and our award-winning platform has happy customers and tons of press coverage.
# Connect
# with me for more!
# April 21, 2025
# The Complete Agentic AI Engineering Course
# January 23, 2025
# LLM Workshop – Hands-on with Agents – resources
# December 21, 2024
# Welcome, SuperDataScientists!
# November 13, 2024
# Mastering AI and LLM Engineering – Resources
# Navigation
# Home
# Connect Four
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook
# Subscribe to newsletter
# Type your email…
# Subscribe

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/nvidia/parakeet-tdt-0.6b-v2',
#  '/ACE-Step/ACE-Step-v1-3.5B',
#  '/Lightricks/LTX-Video',
#  '/nari-labs/Dia-1.6B',
#  '/lodestones/Chroma',
#  '/models',
#  '/spaces/smolagents/computer-agent',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/ACE-Step/ACE-Step',
#  '/spaces/ByteDance/DreamO',
#  '/spaces/RiverZ/ICEdit',
#  '/spaces',
#  '/datasets/DMindAI/DMind_Benchmark',
#  '/datasets/nvidia/OpenCodeReasoning',
#  '/datasets/nvidia/Nemotron-CrossThink',
#  '/datasets/nvidia/OpenMathReasoning',
#  '/datasets/openbmb/Ultra-FineWeb',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord',
#  'https://www.zhihu.com/org/huggingface',
#  'https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/blog/chinese-language-blog/wechat.jpg']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community page', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussions', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# nvidia/parakeet-tdt-0.6b-v2
# Updated
# 12 days ago
# •
# 109k
# •
# 786
# ACE-Step/ACE-Step-v1-3.5B
# Updated
# about 13 hours ago
# •
# 383
# Lightricks/LTX-Video
# Updated
# 7 days ago
# •
# 250k
# •
# 1.44k
# nari-labs/Dia-1.6B
# Updated
# 8 days ago
# •
# 159k
# •
# 2.1k
# lodestones/Chroma
# Updated
# 2 days ago
# •
# 471
# Browse 1M+ models
# Spaces
# Running
# on
# CPU Upgrade
# 514
# 514
# Computer Agent
# 🖥
# Run tasks using an AI-powered computer agent
# Running
# 6.46k
# 6.46k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 298
# 298
# ACE Step
# 😻
# A Step Towards Music Generation Foundation Model
# Running
# on
# Zero
# 241
# 241
# DreamO
# 🐨
# A Unified Framework for Image Customization
# Running
# on
# Zero
# 505
# 505
# ICEdit
# 🖼
# Universal Image Editing is worth a single LoRA
# Browse 400k+ applications
# Datasets
# DMindAI/DMind_Benchmark
# Updated
# 3 days ago
# •
# 1.82k
# •
# 62
# nvidia/OpenCodeReasoning
# Updated
# 9 days ago
# •
# 15.7k
# •
# 397
# nvidia/Nemotron-CrossThink
# Updated
# 12 days ago
# •
# 12.5k
# •
# 91
# nvidia/OpenMathReasoning
# Updated
# 4 days ago
# •
# 34.2k
# •
# 219
# openbmb/Ultra-FineWeb
# Updated
# 5 days ago
# •
# 1.23k
# •
# 33
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 757 models
# •
# 3.25k followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 5.91k followers
# Amazon
# company
# •
# 20 models
# •
# 3.15k followers
# Google
# company
# •
# 991 models
# •
# 13.1k followers
# Intel
# company
# •
# 221 models
# •
# 2.53k followers
# Microsoft
# company
# •
# 374 models
# •
# 12.3k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 160 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 267 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 144,275
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 28,955
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,260
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,593
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,679
# Fast tokenizers optimized for research & production
# TRL
# 13,697
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,575
# State-of-the-art ML running directly in your browser
# smolagents
# 18,561
# Smol library to build great agents in Python
# PEFT
# 18,378
# Parameter-efficient finetuning for large language models
# Datasets
# 20,104
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,115
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,706
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 37,351
# AI & ML interests
# The AI community building the future.
# Recent Activity
# clem
# new
# activity
# about 4 hours ago
# huggingface/InferenceSupport:
# crystalwizard/Rustic-Whimsy-SD3.5-Large-Lora
# pagezyhf
# updated
# a dataset
# about 8 hours ago
# huggingface/documentation-images
# coyotte508
# updated
# a Space
# about 9 hours ago
# huggingface/space-build
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 42
# Team members
# 215
# +181
# +168
# +147
# +137
# +117
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 233k
# •
# 45
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 11.8M
# •
# •
# 680
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 8.13M
# •
# 187
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 4.33M
# •
# •
# 757
# spaces
# 26
# Sort:
# 		Recently updated
# pinned
# Running
# 87
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 4
# Space Build
# 🐨
# Generate static files for spaces
# huggingface
# about 9 hours ago
# Running
# 162
# Inference Playground
# 🔋
# Adjust website theme based on user settings
# huggingface
# 1 day ago
# Running
# 397
# AI Deadlines
# ⚡
# Generate project deadlines
# huggingface
# 15 days ago
# Running
# 94
# InferenceSupport
# 💥
# Discussions about the Inference Providers feature on the Hub
# huggingface
# 27 days ago
# Running
# 538
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Expand
# 							26
# 								spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/timesfm-tourism-monthly
# Updated
# Mar 31
# •
# 255
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 724
# •
# •
# 61
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 28
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 18.9k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 261
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 18.6k
# •
# 6
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 4.96k
# •
# 21
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 46
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 95.5k
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand
# 							16
# 								models
# datasets
# 42
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 8 hours ago
# •
# 52
# •
# 2.74M
# •
# 63
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 6 days ago
# •
# 1.67k
# •
# 1.2k
# •
# 23
# huggingface/badges
# Viewer
# •
# Updated
# Apr 8
# •
# 1
# •
# 1.62M
# •
# 43
# huggingface/policy-docs
# Updated
# Mar 20
# •
# 1.35k
# •
# 10
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# Mar 15
# •
# 69
# •
# 888
# •
# 7
# huggingface/gemini-results-2025-03-03
# Viewer
# •
# Updated
# Mar 4
# •
# 17
# •
# 32
# huggingface/gemini-results-2025-02-28
# Viewer
# •
# Updated
# Mar 1
# •
# 21
# •
# 36
# huggingface/gemini-results-2025-02-27
# Viewer
# •
# Updated
# Feb 28
# •
# 24
# •
# 31
# huggingface/gemini-results-2025-02-25
# Viewer
# •
# Updated
# Feb 26
# •
# 32
# •
# 78
# huggingface/gemini-results-2025-02-24
# Viewer
# •
# Updated
# Feb 25
# •
# 32
# •
# 35
# Expand
# 							42
# 								datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 360 models
# •
# 25.5k followers
# Shopify
# Enterprise
# company
# •
# 452 followers
# AMD
# Enterprise
# company
# •
# 132 models
# •
# 1.53k followers
# Together
# Enterprise
# company
# •
# 29 models
# •
# 592 followers
# Qwen
# Enterprise
# company
# •
# 274 models
# •
# 30.6k followers
# Xsolla
# Enterprise
# company
# •
# 136 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 114 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 97 followers
# IBM Granite
# Enterprise
# company
# •
# 117 models
# •
# 1.7k followers
# creditkarma
# Enterprise
# company
# •
# 64 followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 72 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 59 followers
# Liquid AI
# Enterprise
# company
# •
# 192 followers
# Lightricks
# Enterprise
# company
# •
# 11 models
# •
# 848 followers
# Infosys Limited
# Enterprise
# company
# •
# 2 models
# •
# 823 followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 297 followers
# Snowflake
# Enterprise
# company
# •
# 21 models
# •
# 507 followers
# Arm
# Enterprise
# company
# •
# 194 followers
# LiveRAG by AIIR
# Enterprise
# company
# •
# 129 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 266 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 163 followers
# Jusbrasil
# Enterprise
# company
# •
# 97 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 425 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 65 models
# •
# 1.33k followers
# HyperCLOVA X
# Enterprise
# company
# •
# 3 models
# •
# 285 followers
# Widn AI
# Enterprise
# company
# •
# 48 followers
# BCG X
# Enterprise
# company
# •
# 40 followers
# Adyen
# Enterprise
# company
# •
# 64 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 43k followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 5.91k followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 221 followers
# ServiceNow
# Enterprise
# company
# •
# 502 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 267 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 144 followers
# Fidelity Investments
# Enterprise
# company
# •
# 141 followers
# TNG Technology Consulting GmbH
# Enterprise
# company
# •
# 3 models
# •
# 141 followers
# Aledade Inc
# Enterprise
# company
# •
# 71 followers
# Chegg Inc
# Enterprise
# company
# •
# 86 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 160 followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 638 followers
# Stability AI
# Enterprise
# company
# •
# 105 models
# •
# 23k followers
# freepik
# Enterprise
# company
# •
# 6 models
# •
# 276 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# Pro Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 5x more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# Pro Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get Pro
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with H200 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Blazingly fast whisper transcriptions with Inference Endpoints
# By
# mfuntowicz
# May 13, 2025
# •
# 17
# Community Articles
# view all
# CircleGuardBench: New Standard for Evaluating AI Moderation Models
# By
# whitecircle-ai
# and 7 others
# •
# 7 days ago
# •
# 51
# Page-to-Video: Generate videos from webpages 🪄🎬
# By
# burtenshaw
# •
# 8 days ago
# •
# 23
# Good answers are not necessarily factual answers: an analysis of hallucination in leading LLMs
# By
# davidberenstein1957
# and 1 other
# •
# 7 days ago
# •
# 20
# I trained a Language Model to schedule events with GRPO!
# By
# anakin87
# •
# 14 days ago
# •
# 66
# AI Personas: The Impact of Design Choices
# By
# giadap
# and 1 other
# •
# 7 days ago
# •
# 13
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 243
# Reduce, Reuse, Recycle: Why Open Source is a Win for Sustainability
# By
# sasha
# and 1 other
# •
# 6 days ago
# •
# 12
# 🦸🏻#17: What is A2A and why is it – still! – underappreciated?
# By
# Kseniase
# •
# 6 days ago
# •
# 9
# CycleNavigator: Visualizing Economic and Political Cycles Through AI
# By
# openfree
# •
# about 6 hours ago
# •
# 9
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 552
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 132
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 71
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 132
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 32
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 64
# Agent Leaderboard: Evaluating AI Agents in Multi-Domain Scenarios
# By
# pratikbhavsar
# and 1 other
# •
# Feb 12
# •
# 20
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 173
# What is test-time compute and how to scale it?
# By
# Kseniase
# and 1 other
# •
# Feb 6
# •
# 85
# Reasoning Datasets Competition
# By
# bespokelabs
# and 6 others
# •
# Apr 9
# •
# 33
# Bamba-9B-v2 - Fast and powerful!
# By
# ibm-ai-platform
# and 12 others
# •
# 15 days ago
# •
# 29
# Vision Language Models (Better, Faster, Stronger)
# By
# merve
# May 12, 2025
# •
# 197
# LeRobot Community Datasets: The “ImageNet” of Robotics — When and How?
# By
# danaaubakirova
# May 11, 2025
# •
# 44
# How to Build an MCP Server with Gradio
# By
# abidlabs
# April 30, 2025
# •
# 95
# Welcoming Llama Guard 4 on Hugging Face Hub
# By
# merve
# April 29, 2025
# •
# 34
# The 4 Things Qwen-3's Chat Template Teaches Us
# By
# cfahlgren1
# April 30, 2025
# •
# 34
# Tiny Agents: a MCP-powered agent in 50 lines of code
# By
# julien-c
# April 25, 2025
# •
# 231
# Introducing AutoRound: Intel’s Advanced Quantization for LLMs and VLMs
# By
# wenhuach
# April 29, 2025
# •
# 25
# 17 Reasons Why Gradio Isn't Just Another UI Library
# By
# ysharma
# April 16, 2025
# •
# 31
# Cohere on Hugging Face Inference Providers 🔥
# By
# burtenshaw
# April 16, 2025
# •
# 124
# Introducing HELMET
# By
# hyen
# April 16, 2025
# •
# 26
# Hugging Face to sell open-source robots thanks to Pollen Robotics acquisition 🤖
# By
# thomwolf
# April 14, 2025
# •
# 45
# 4M Models Scanned: Protect AI + Hugging Face 6 Months In
# By
# sean-pai
# April 14, 2025
# •
# 29
# Hugging Face and Cloudflare Partner to Make Real-Time Speech and Video Seamless with FastRTC
# By
# freddyaboulton
# April 9, 2025
# •
# 26
# Arabic Leaderboards: Introducing Arabic Instruction Following, Updating AraGen, and More
# By
# alielfilali01
# April 8, 2025
# guest
# •
# 16
# Previous
# 1
# 2
# 3
# ...
# 41
# Next
# Community Articles
# Sort:
# 		Trending
# CircleGuardBench: New Standard for Evaluating AI Moderation Models
# By
# whitecircle-ai
# and 7 others
# •
# 7 days ago
# •
# 51
# Page-to-Video: Generate videos from webpages 🪄🎬
# By
# burtenshaw
# •
# 8 days ago
# •
# 23
# Good answers are not necessarily factual answers: an analysis of hallucination in leading LLMs
# By
# davidberenstein1957
# and 1 other
# •
# 7 days ago
# •
# 20
# I trained a Language Model to schedule events with GRPO!
# By
# anakin87
# •
# 14 days ago
# •
# 66
# AI Personas: The Impact of Design Choices
# By
# giadap
# and 1 other
# •
# 7 days ago
# •
# 13
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 243
# Reduce, Reuse, Recycle: Why Open Source is a Win for Sustainability
# By
# sasha
# and 1 other
# •
# 6 days ago
# •
# 12
# 🦸🏻#17: What is A2A and why is it – still! – underappreciated?
# By
# Kseniase
# •
# 6 days ago
# •
# 9
# CycleNavigator: Visualizing Economic and Political Cycles Through AI
# By
# openfree
# •
# about 6 hours ago
# •
# 9
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 552
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 132
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 71
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 132
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 32
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 64
# Agent Leaderboard: Evaluating AI Agents in Multi-Domain Scenarios
# By
# pratikbhavsar
# and 1 other
# •
# Feb 12
# •
# 20
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 173
# What is test-time compute and how to scale it?
# By
# Kseniase
# and 1 other
# •
# Feb 6
# •
# 85
# Reasoning Datasets Competition
# By
# bespokelabs
# and 6 others
# •
# Apr 9
# •
# 33
# Bamba-9B-v2 - Fast and powerful!
# By
# ibm-ai-platform
# and 12 others
# •
# 15 days ago
# •
# 29
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community discussions
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# I could not take exam of LLM course
# Course
# 1
# 25
# May 13, 2025
# Need help about speaker identifier app provided by Lyn68
# Beginners
# 1
# 6
# May 13, 2025
# Persistent DNS Resolution Errors
# Spaces
# 19
# 308
# May 10, 2025
# Dataset Viewer not available on features of type datasets.Array2D(shape=(None, 768), dtype='float64')
# 🤗Datasets
# 2
# 12
# May 13, 2025
# Chapter 1 questions
# Course
# 105
# 23018
# May 13, 2025
# Potential issue with spaces analytics not working
# Spaces
# 3
# 25
# May 13, 2025
# How can I make my fine-tuned model supported by inference providers?
# Beginners
# 1
# 19
# May 13, 2025
# Facing issue using a model hosted on HuggingFace Server and talking to it using API_KEY
# Beginners
# 7
# 54
# May 12, 2025
# But is there even a single model working here?!
# Models
# 4
# 248
# May 10, 2025
# Open-source RL Model for Predicting Sales Conversion from Conversations + Free Agent Platform (Dataset, Model, Paper, Demo)
# Models
# 0
# 11
# May 13, 2025
# Llama 4 access pending
# Beginners
# 12
# 150
# May 13, 2025
# HF Agent Course Finalassignment
# Spaces
# 1
# 12
# May 13, 2025
# Word embeddings via http call: error 404
# Beginners
# 1
# 42
# May 10, 2025
# Need a Image Post gemerator
# Spaces
# 1
# 22
# May 12, 2025
# Inference API stopped working
# Inference Endpoints on the Hub
# 43
# 1889
# May 9, 2025
# I get this error when training a lora for flux
# Beginners
# 3
# 24
# May 12, 2025
# Cerebras Inference Error
# Inference Endpoints on the Hub
# 0
# 12
# May 12, 2025
# Issue Accessing GPU After Entering Payment Details – Space Stuck on Loading
# Beginners
# 2
# 14
# May 12, 2025
# Page jump issue
# Beginners
# 1
# 9
# May 12, 2025
# Multiple Spaces have stopped working
# Beginners
# 5
# 111
# May 13, 2025
# Matching Single Shoes with Computer Vision – Alternatives to Cosine Similarity and Siamese Networks need advice
# Intermediate
# 3
# 7
# May 12, 2025
# I am getting this error on langchain
# Beginners
# 10
# 483
# May 11, 2025
# Gradio Space Crashing on Startup - TypeError: argument of type 'bool' is not iterable
# Spaces
# 2
# 23
# May 11, 2025
# Issue with ZeroGPU Quota on Hugging Face Pro Account
# Beginners
# 1
# 28
# May 11, 2025
# Mamba2 Cache Position
# 🤗Transformers
# 4
# 103
# May 12, 2025
# Error in HF Space Docker
# Beginners
# 15
# 397
# April 22, 2025
# Building something that help people who really need help using ai
# 🤗Transformers
# 4
# 36
# May 12, 2025
# 500 Internal Error - We're working hard to fix this as soon as possible
# 🤗Transformers
# 44
# 1685
# April 25, 2025
# Where in the TOS does it specify usage of things created with Deepsite?
# Beginners
# 1
# 24
# May 10, 2025
# Persistent 404 Not Found Errors with Public Inference API
# Inference Endpoints on the Hub
# 4
# 128
# May 13, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Appearance settings
# Reseting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 48.8k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 144k
# 28.9k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 29k
# 6k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.1k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18.4k
# 1.9k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.7k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.9k
# 536
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 312 repositories
# xet-core
# Public
# xet client tech, used in huggingface_hub
# huggingface/xet-core’s past year of commit activity
# Rust
# 93
# Apache-2.0
# 12
# 8
# 11
# Updated
# May 14, 2025
# lighteval
# Public
# Lighteval is your all-in-one toolkit for evaluating LLMs across multiple backends
# huggingface/lighteval’s past year of commit activity
# Python
# 1,531
# MIT
# 241
# 97
# (1 issue needs help)
# 27
# Updated
# May 13, 2025
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 144,275
# Apache-2.0
# 28,925
# 1,044
# (2 issues need help)
# 740
# Updated
# May 13, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 28,955
# Apache-2.0
# 5,956
# 492
# (11 issues need help)
# 183
# Updated
# May 13, 2025
# hfendpoints
# Public
# SDK for creating Hugging Face Inference Endpoints deployments
# huggingface/hfendpoints’s past year of commit activity
# Rust
# 6
# 1
# 0
# 1
# Updated
# May 13, 2025
# transformers.js
# Public
# State-of-the-art Machine Learning for the web. Run 🤗 Transformers directly in your browser, with no need for a server!
# huggingface/transformers.js’s past year of commit activity
# JavaScript
# 13,575
# Apache-2.0
# 916
# 335
# (3 issues need help)
# 58
# Updated
# May 13, 2025
# huggingface.js
# Public
# Utilities to use the Hugging Face Hub API
# huggingface/huggingface.js’s past year of commit activity
# TypeScript
# 1,667
# MIT
# 376
# 106
# (5 issues need help)
# 50
# Updated
# May 13, 2025
# dell-ai
# Public
# The official Python SDK and CLI for the Dell Enterprise Hub
# huggingface/dell-ai’s past year of commit activity
# Python
# 2
# Apache-2.0
# 1
# 4
# 2
# Updated
# May 13, 2025
# trl
# Public
# Train transformer language models with reinforcement learning.
# huggingface/trl’s past year of commit activity
# Python
# 13,697
# Apache-2.0
# 1,872
# 382
# 67
# Updated
# May 13, 2025
# huggingface_hub
# Public
# The official Python client for the Huggingface Hub.
# huggingface/huggingface_hub’s past year of commit activity
# Python
# 2,593
# Apache-2.0
# 703
# 163
# (5 issues need help)
# 21
# Updated
# May 13, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 534 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning Advocacy @ 🤗 Hugging Face
# 10h
# Report this post
# AgentCPM-GUI from Open BMB looks like an interesting GUI agent model to watch. It's a smaller model at 7 billion parameters but beats models like Gemini-2.0 on mobile UI control benchmarks.
#
# model:
# https://lnkd.in/eFbgCHzg
# dataset:
# https://lnkd.in/e5xjFZ2M
# repo:
# https://lnkd.in/eGuQz2KP
# 33
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian at 🤗
# 16h
# Report this post
# What’s new in reasoning datasets?
#
# Over the past few months, we’ve seen the release of many high-quality datasets on
# Hugging Face
# that aim to stretch the reasoning capabilities of language models — from symbolic mathematics to multimodal understanding and academic intuition.
#
# Here’s a short roundup of *some* of these datasets
#
# 📘 DeepMath-103K
#
# A meticulously curated dataset of over 100K advanced math problems, each with verified answers, difficulty ratings, and multiple reasoning paths.
#
# It supports both supervised and reinforcement learning (RL), and has already enabled new SOTA results (85.5% on MATH 500 using a 7B model).
#
# Great for training models that reason through complex, multi-step calculations — and for evaluating them fairly, thanks to careful decontamination.
#
# Dataset:
# https://lnkd.in/evJD9xvN
# ---
#
# 🖼️ MMPR-v1.2
#
# This massive 3M+ example dataset focuses on multimodal reasoning preferences.
#
# Built to train InternVL2 with Mixed Preference Optimization (MPO), it significantly improves performance on MathVista and other VQA benchmarks — and reduces hallucinations along the way.
#
# What stands out is the balance of scale, diversity, and targeted data curation for visual reasoning tasks.
#
# Dataset:
# https://lnkd.in/eHu_jamK
# ---
#
# 🔬 Academic Reasoning and Intuition Chains
#
# This dataset builds structured reasoning chains directly from open-access scientific papers — focusing on pre-experimental intuition and conceptual thinking.
#
# Each example includes <think> tags, domain labels, and LLM-based verification to ensure the chains reflect genuine reasoning (not result summaries).
#
# Ideal for training models that “think like a researcher,” especially in STEM domains.
#
# Dataset:
# https://lnkd.in/emUz-BuD
# ---
#
# 🧪 MMK12
#
# A high-quality multimodal reasoning dataset built entirely from real-world images and questions — spanning maths, physics, chemistry, and biology.
#
# Unlike synthetic benchmarks, the QA pairs here are verified by humans and sourced from real contexts.
#
# Used to train MM-EUREKA, which ranks just behind GPT-4o and o1 on relevant multimodal science tasks.
#
# Dataset:
# https://lnkd.in/eAEAQsf4
# ---
#
# and finally my own modest contribution!
#
# 📚 Fine Reasoning Questions
#
# Most reasoning datasets focus on math, code, or science. This one takes a different approach — generating reasoning questions from web texts in domains like finance, politics, and the environment.
#
# It’s a proof-of-concept that shows how using models like Qwen + the Curator  library can be used to generate high-quality, domain-specific questions from raw web data.
#
# It’s also tagged by whether the question requires the original context — making it useful for both open- and closed-book tasks.
#
# Dataset:
# https://lnkd.in/enCDrJ_B
# Excited to see what the next few months brings!
# 102
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗 | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 1d
# Report this post
# VLMS 2025 UPDATE 🔥
#
# We just shipped a blog on everything latest on vision language models, including
# 🤖 GUI agents, agentic VLMs, omni models
# 📑 multimodal RAG
# ⏯️ video LMs
# 🤏🏻 smol models
# ..and more!
#
# find it in comments 💬
# 972
# 23 Comments
# Like
# Comment
# Share
# Hugging Face
# 955,614 followers
# 1d
# Report this post
# How do you call a model that can understand two or more modalities and output two or more modalities? 💡
# Julien Chaumond
# CTO at Hugging Face
# 1d
# A new task has appeared on
# Hugging Face
# 👀
#
# What is it?
#
# In the HF taxonomy (tasksonomy? 🥁), Any-to-any are models that can understand two or more modalities and output two or more modalities.
#
# A popular such model that came out in April is
# Qwen
# Omni.
# It can take, for instance:
# - text + video + audio as input
# - text + audio as output
#
# It's supported natively in transformers!
#
# Thanks
# Merve Noyan
# for pushing those models <3
# 89
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# 955,614 followers
# 2d
# Report this post
# PSA for local AI x VLM fans:
# Julien Chaumond
# CTO at Hugging Face
# 3d
# Attention 📣:
# llama.cpp
# server and Web UI are now compatible with VLMs ‼️
#
# meaning the
# llama.cpp
# now has eyes 👁️
#
# Shout out to
# Georgi Gerganov
# and the GGML and HF teams, and in particular to the great
# Xuan-Son Nguyen
# , for shipping this much-awaited feature! 🤗
#
# Give it a try today (upgrade your local binary), example commands in the snippet below:
#
# the GGML team shared a bunch of pre-quantized models, ready to be used, from:
# - Google Gemma
# - Mistral's Pixtral
# - Qwen VL
# - SmolVLM
# 188
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 4d
# Report this post
# Initializing each model in a DiffusionPipeline & then quantizing them to perform full inference is a painful dev experience 🥲
#
# Today, we're shipping something you'll love -- pipeline-level quantization. Pass a quant config directly while `DiffusionPipeline.from_pretrained()` 🔥
#
# The example above is the easiest entry point. But maybe you want more flexibility. For example, have different quantization configs for different components.
#
# Specify configs, not entire models. You retain all the flexibility, but with more ease 🤗
#
# 📜 Docs:
# https://lnkd.in/gMHKePEz
# 👨💻 PR:
# https://lnkd.in/gixRmKc6
# 176
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 63,460 followers
# 4d
# Report this post
# Try Tencent's new Primitive-Anything app:
# https://lnkd.in/gG9zdH6j
# 🥇 First AI that breaks down complex 3D objects into simple geometric building blocks just like us humans do
# 🤙 Works on anything -- furniture to vehicles to characters
# 🎮 Perfect for game design, 3D modeling
# …more
# 202
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Aymeric Roucher
# Leading agents @ Hugging Face 🤗 | Polytechnique - Cambridge
# 4d
# Edited
# Report this post
# I've made an open version of Google's NotebookLM, and it shows the superiority of the open source tech stack! 💪
#
# The app's workflow is simple. Given a source PDF or URL, it extracts the content from it, then tasks
# Meta
# 's Llama 3.3-70B, with writing the podcast script, with a good prompt crafted by
# Gabriel Chua
# ("two hosts, with lively discussion, fun notes, insightful question etc.")
# Then it hands off the text-to-speech conversion to Kokoro-82M, and there you go, you have two hosts discussion any article.
#
# The generation is nearly instant, because:
# > Llama 3.3 70B is running at 1,000 tokens/seconds with
# Cerebras Systems
# inference
# > The audio is generated in streaming mode by the tiny (yet powerful) Kokoro, generating voices faster than real-time.
#
# And the audio generation runs for free on Zero GPUs, hosted by HF on H200s.
#
# Overall, open source solutions rival the quality of closed-source solutions at close to no cost!
#
# Generate your podcast here:
# https://lnkd.in/eKiRRxGr
# 586
# 31 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Clem Delangue 🤗
# Clem Delangue 🤗 is an Influencer
# Co-founder & CEO at Hugging Face
# 5d
# Report this post
# Nvidia dominating the top trending open datasets!
# 494
# 15 Comments
# Like
# Comment
# Share
# Hugging Face
# 955,614 followers
# 5d
# Report this post
# An improved version of the Segment Anything Model is now available in the Transformers library. Read more below:
# Niels Rogge
# Machine Learning Engineer at ML6 & Hugging Face
# 5d
# Edited
# New model addition in
# Hugging Face
# Transformers: HQ-SAM (High-Quality Segment Anything Model)! 🔥
#
# This model upgrades SAM, the Segment Anything Model introduced by
# Meta
# in 2023, with the ability to accurately segment fine-grained objects, while maintaining SAM’s original promptable design, efficiency, and zero-shot generalizability. Hence it's a drop-in replacement.
#
# It does so by adding a minimal set of learnable parameters to the pre-trained model weights of SAM. The authors composed a dataset of 44K fine-grained segmentation masks from several sources. Next they trained HQ-SAM on those, which only took 4 hours on 8 GPUs. The original parameters of SAM were kept frozen.
#
# The additional parameters consist of 2 components: a High-Quality Token and Global-local Feature Fusion. This work was presented at NeurIPS, one of the most prestigious AI conferences in the world, in 2023. It still holds the SOTA for zero-shot segmentation on the SGinW (Segmentation-in-the-Wild) benchmark.
#
# It is now easily usable in a few lines of code thanks to the amazing contribution by
# Sushmanth Reddy Mereddy
# .
#
# Get started here:
#
# - Docs:
# https://lnkd.in/e5iDT6Tf
# - Models:
# https://lnkd.in/ehS6ZUyv
# - Notebook:
# https://lnkd.in/eg5qiKC2
# 690
# 15 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Your California Privacy Choices
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'docs page', 'url': 'https://huggingface.co/docs'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nnvidia/parakeet-tdt-0.6b-v2\nUpdated\n12 days ago\n•\n109k\n•\n786\nACE-Step/ACE-Step-v1-3.5B\nUpdated\nabout 13 hours ago\n•\n384\nLightricks/LTX-Video\nUpdated\n7 days ago\n•\n250k\n•\n1.44k\nnari-labs/Dia-1.6B\nUpdated\n8 days ago\n•\n159k\n•\n2.1k\nlodestones/Chroma\nUpdated\n2 days ago\n•\n471\nBrowse 1M+ models\nSpaces\nRunning\non\nCPU Upgrade\n515\n515\nComputer Agent\n🖥\nRun tasks using an AI-powered computer agent\nRunning\n6.46k\n6.46k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n299\n299\nACE Step\n😻\nA Step Towards Music Generation Foundation Model\nRunning\non\nZero\n243\n243\nDreamO\n🐨\nA Unified Framework for Image Customization\nRunning\non\nZero\n507\n507\nICEdit\n🖼\nUniversal Image Editing is worth a single LoRA\nBrowse 400k+ applications\nDatasets\nDMindAI/DMind_Benchmark\nUpdated\n3 days ago\n•\n1.82k\n•\n62\nnvidia/OpenCodeReasoning\nUpdated\n9 days ago\n•\n15.7k\n•\n398\nnvidia/Nemotron-CrossThink\nUpdated\n12 days ago\n•\n12.5k\n•\n91\nnvidia/OpenMathReasoning\nUpdated\n4 days ago\n•\n34.2k\n•\n219\nopenbmb/Ultra-FineWeb\nUpdated\n5 days ago\n•\n1.23k\n•\n33\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n757 models\n•\n3.25k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.12k models\n•\n5.91k followers\nAmazon\ncompany\n•\n20 models\n•\n3.16k followers\nGoogle\ncompany\n•\n991 models\n•\n13.1k followers\nIntel\ncompany\n•\n221 models\n•\n2.53k followers\nMicrosoft\ncompany\n•\n374 models\n•\n12.3k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n160 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n267 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n144,275\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n28,955\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,260\nSafe way to store/distribute neural network weights\nHub Python Library\n2,593\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,679\nFast tokenizers optimized for research & production\nTRL\n13,697\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,575\nState-of-the-art ML running directly in your browser\nsmolagents\n18,561\nSmol library to build great agents in Python\nPEFT\n18,378\nParameter-efficient finetuning for large language models\nDatasets\n20,104\nAccess & share datasets for any ML tasks\nText Generation Inference\n10,115\ ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'home page', 'url': 'https://huggingface.co/'}, {'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# # Hugging Face Brochure
#
# ---
#
# ## **About Us**
#
# Hugging Face is a vibrant community dedicated to advancing artificial intelligence. Serving as the centerpiece for collaboration among machine learning enthusiasts, we facilitate the sharing and development of models, datasets, and applications, making AI accessible to all.
#
# > **"The AI community building the future."**
#
# ---
#
# ## **What We Offer**
#
# - **Explore AI Apps:** Dive into a plethora of applications showcasing the latest innovations in AI.
# - **1M+ Models Available:** Browse through an extensive library of trending models, including:
#   - `nvidia/parakeet-tdt-0.6b-v2`
#   - `ACE-Step/ACE-Step-v1-3.5B`
#   - `Lightricks/LTX-Video`
#
# - **Datasets Galore:** Access over 250k datasets to drive your machine learning projects forward.
#
# ---
#
# ## **Our Community**
#
# Join a diverse group of over 50,000 organizations, including industry leaders like:
# - **Amazon**
# - **Google**
# - **Microsoft**
# - **Meta**
#
# We believe in open-source collaboration and support, fostering a space where everyone can share ideas, innovations, and findings.
#
# ---
#
# ## **Company Culture**
#
# At Hugging Face, we thrive on collaboration, transparency, and community engagement. Our culture is built on:
# - **Innovation:** Encouraging fresh ideas and methodologies.
# - **Support:** Providing dedicated assistance for both individuals and enterprises.
# - **Inclusivity:** Welcoming everyone from seasoned developers to curious beginners.
#
# ---
#
# ## **Careers at Hugging Face**
#
# We are always on the lookout for passionate individuals who want to shape the future of AI with us. Opportunities exist across various fields including engineering, marketing, and support.
#
# ### **Why Join Us?**
# - Work in a dynamic environment filled with talented professionals.
# - Contribute to meaningful projects that have a global impact.
# - Enjoy a competitive salary and benefits package including flexibility in work.
#
# [**Explore Career Opportunities**](#)
#
# ---
#
# ## **Get Involved**
#
# Ready to start your journey with Hugging Face?
#
# - **Sign Up today** and become a part of the AI revolution.
# - Follow us on our community forums, GitHub, Discord, and social media platforms to stay updated on the latest news, releases, and events.
#
# For more information, visit our [website](#) or check out our [documentation](#) and [blog](#) for insights and tutorials.
#
# ---
#
# Hugging Face is where AI enthusiasts come together to break new ground. Join us in building the future!

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussions', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# # Hugging Face Brochure
#
# ## The AI Community Building the Future
#
# Hugging Face is at the forefront of the Artificial Intelligence (AI) and Machine Learning (ML) revolution. We provide a collaborative platform designed for developers, researchers, and organizations to explore, share, and build upon a vast array of ML models and datasets. With over **1 million models** and **250,000 datasets**, we're committed to democratizing access to advanced AI technologies.
#
# ---
#
# ### What We Offer
#
# - **Collaborative Platform**: Engage with the ML community to host and collaborate on public models, datasets, and applications.
# - **Diverse Applications**: Explore AI applications in text, image, video, audio, and 3D modalities.
# - **Enterprise Solutions**: We offer enterprise-grade solutions with optimal security and support, making it easier for organizations to harness the power of AI.
#
# ---
#
# ### Trusted by Leading Organizations
#
# Join more than **50,000 organizations** utilizing Hugging Face, including giants like:
#
# - **Google**: 991 models
# - **Microsoft**: 374 models
# - **Amazon**: 20 models
# - **Meta**: 2,120 models
# - **Grammarly**: 10 models
#
# We empower businesses to innovate faster with the latest ML technologies.
#
# ---
#
# ### Company Culture
#
# At Hugging Face, we're on a mission to **democratize good machine learning** through collaboration and transparency. Our diverse team of 215+ professionals thrives in a culture of openness, continuous learning, and community engagement. We believe that together, we can create a better future powered by AI.
#
# - **Community-Driven**: Our platform is built with contributions from developers around the globe.
# - **Innovative Spirt**: We encourage creative solutions to complex problems, fostering an environment where experimentation is key.
#
# ---
#
# ### Careers at Hugging Face
#
# Join our vibrant team and help shape the future of AI! We value:
#
# - **Diversity**: A team that reflects a variety of perspectives for innovative ideas.
# - **Growth**: Opportunities for professional development and learning.
# - **Impact**: Work on cutting-edge technologies and contribute to significant advancements in AI.
#
# If you’re passionate about pushing the boundaries of technology, explore our [career opportunities](https://huggingface.co/jobs) and join us today!
#
# ---
#
# ### Get Started
#
# Whether you're a researcher looking to publish your models, a developer seeking to deploy applications, or a company wanting to integrate AI capabilities, Hugging Face has everything you need to succeed.
#
# **Explore** our platform, discover innovative tools, and join us in building the future of AI. Visit: [Hugging Face](https://huggingface.co) and start making extraordinary advancements with us!
#
# ---
#
# *Join the Hugging Face community today and be part of the future of AI!*

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face
#
# **The AI community building the future.**
#
# At Hugging Face, we aim to create an open and collaborative platform for the machine learning (ML) community. Here, developers, researchers, and companies can work together to build advanced AI applications using models, datasets, and resources that promote innovation and excellence.
#
# ### Our Offerings
#
# - **Models**: Explore over 1 million models, including trending ones like nvidia/parakeet-tdt-0.6b-v2 and ACE-Step/ACE-Step-v1-3.5B.
# - **Datasets**: Access to expansive datasets for any ML task, with more than 250k datasets available.
# - **Spaces**: Run applications and tasks using AI-powered agents—like image customization and music generation—with our built-in spaces.
#
# ### Who We Serve
#
# Hugging Face is leveraged by over **50,000 organizations** worldwide, including industry giants like:
# - **Meta**
# - **Amazon**
# - **Google**
# - **Microsoft**
# - **Grammarly**
#
# Join a community that collaborates across various professions, from enterprises to non-profits, all working towards advancing AI.
#
# ### Culture and Community
#
# At Hugging Face, we are dedicated to an **open-source ethos** that emphasizes collaboration and transparency. Our platform not only allows individuals to share their work but also provides the tools to build portfolios, learn, and grow professional skills. We believe in building products with the community, ensuring everyone has the opportunity to contribute and innovate.
#
# ### Careers at Hugging Face
#
# Looking to advance your career in AI? Hugging Face offers:
# - An innovative and supportive work environment where creativity thrives.
# - Opportunities to work with cutting-edge technology.
# - A community-centric workplace that fosters collaboration and learning.
#
# Join us in shaping the future of AI and be a part of our dynamic team. Check out our **[Careers page](#)** for the latest job openings.
#
# ### Get Started Today
#
# Ready to dive into the world of AI with us? We invite you to:
# - **Sign Up** and start leveraging a vast array of resources.
# - Explore our paid Compute and Enterprise solutions designed for scaling and securing your ambitious projects.
#
# #### Contact Us
#
# For inquiries regarding enterprise solutions or partnerships, reach out via our official channels. Connect with us on **[GitHub](#)**, **[Twitter](#)**, **[LinkedIn](#)**, or join our community on **[Discord](#)**!
#
# ---
#
# Together, let's build the future of AI—join the Hugging Face community today!

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
